# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display

from pathlib import Path
import pandas as pd
import numpy as np
import dask.dataframe as dd
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
from pycytominer import aggregate, normalize, feature_select
from pycytominer.cyto_utils import load_profiles

# %%
def aggregate_cellprofiler_outputs(data_dir):
    """
    Aggregate CellProfiler outputs from multiple compartments into a single combined file.
    Optimized to reduce DataFrame fragmentation.
    
    Parameters:
    -----------
    data_dir : str
        Path to directory containing CellProfiler output CSV files
        
    Returns:
    --------
    pandas.DataFrame
        Combined DataFrame with all compartment measurements
    """
    compartment_files = {
        "cells": "Cells.csv",
        "cytoplasm": "Cytoplasm.csv",
        "golgi": "GolgiSpots.csv",
        "mito": "MitoObjects.csv",
        "mito_child": "MitoChildObjects.csv",
        "nuclei": "Nuclei.csv",
        "nucleoli": "Nucleoli.csv",
        "nucleoli_child": "NucleoliChildObjects.csv"
    }
    
    def custom_aggregation(df, strata, features, operations):
        """
        Perform multiple aggregation operations efficiently
        
        Parameters:
        -----------
        df : pandas.DataFrame
            Input DataFrame
        strata : list
            Columns to group by
        features : list
            Columns to aggregate
        operations : dict
            Dictionary mapping operation names to functions
            
        Returns:
        --------
        pandas.DataFrame
            Aggregated results
        """
        # Create a copy to avoid fragmentation
        df = df.copy()
        
        # Perform all aggregations at once
        grouped = df.groupby(strata)[features]
        results = []
        
        for op_name, op_func in operations.items():
            result = grouped.agg(op_func).reset_index()
            
            # Rename non-strata columns
            if op_name != 'mean':
                for col in result.columns:
                    if col not in strata:
                        result = result.rename(columns={col: f"{col}_{op_name}"})
            
            results.append(result)
        
        # Merge all results using reduce
        final = reduce(lambda left, right: pd.merge(left, right, on=strata, how='outer'), 
                      results)
        
        return final
    
    def mad(x):
        """Calculate Median Absolute Deviation"""
        median = np.median(x)
        return np.median(np.abs(x - median))
    
    # Define operations
    operations = {
        'mean': 'mean',
        'std': 'std',
        'median': 'median',
        'mad': mad
    }
    
    # Define strata columns
    strata_columns = ["Metadata_Plate", "Metadata_Well"]
    
    # Initialize empty list to store all compartment results
    all_results = []
    
    # Process each compartment
    for compartment, file_path in compartment_files.items():
        try:
            # Load data with copy to avoid fragmentation
            df = pd.read_csv(f"{data_dir}/{file_path}").copy()
            # print(f"Loaded {compartment} data with {len(df)} rows")
            
            # Get feature columns
            feature_cols = [col for col in df.columns 
                          if not col.startswith(("Image_", "Metadata_", "ObjectNumber"))]
            
            # Calculate all aggregations at once
            result = custom_aggregation(df, strata_columns, feature_cols, operations)
            
            # Add object counts
            counts = df.groupby(strata_columns).size().reset_index(name=f'{compartment}_count')
            result = result.merge(counts, on=strata_columns, how='left')
            
            # Add compartment prefix to all non-strata columns
            prefix_cols = {col: f"{compartment}_{col}" 
                         for col in result.columns 
                         if col not in strata_columns}
            result = result.rename(columns=prefix_cols)
            
            all_results.append(result)
            # print(f"Processed {compartment} data")
            
        except FileNotFoundError:
            print(f"Warning: Could not find {file_path}")
            continue
    
    # Merge all compartment results
    final_result = reduce(lambda left, right: pd.merge(left, right, on=strata_columns, how='outer'), 
                         all_results)
    
    # Save combined results
    output_file = f"{data_dir}/combined_measurements.csv"
    final_result.to_csv(output_file, index=False)
    # print(f"\nSaved combined measurements to {output_file}")
    
    return final_result

# Example usage
result = aggregate_cellprofiler_outputs('/mnt/data/cellprofiler-output/inhibitors/compound-001_Plate13_compound-001_13_AA24_conc1.0')

# %%
inhibitor_results = []
for plate in Path('/mnt/data/cellprofiler-output/inhibitors').glob('*'):
    print(plate)
    result = aggregate_cellprofiler_outputs(plate)
    inhibitor_results.append(result)
inhibitor_results_df = pd.concat(inhibitor_results, ignore_index=True)
inhibitor_results_df.to_csv('inhibitor_results.csv', index=False)

# %%
ko_results = []
for plate in Path('/mnt/data/cellprofiler-output/ko').glob('*'):
    print(plate)
    try:
        result = aggregate_cellprofiler_outputs(plate)
        ko_results.append(result)
    except Exception as e:
        print(e)
        continue
ko_results_df = pd.concat(ko_results, ignore_index=True)
ko_results_df.to_csv('ko_results.csv', index=False)
# Out:
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_F04
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_AC34
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_W18
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_W09
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_S32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_F41
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_AD07
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_X02
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_AD02
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_D46
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_Q32
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_J12
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_AD24
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_E22
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_AC39
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_S45
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_I12
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_AE12
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_E13
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_X31
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_J42
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_V05
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_K40
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_T28
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_E46
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_C09
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_J05
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_X47
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_AE45
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_C10
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_V44
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_Q28
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_U37
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_U47
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_V42
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_AA37
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_L05
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_K42
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_Q37
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_O03
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_H18
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_AD09
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_P06
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_C11
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_E12
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_Q06
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_Y17
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_I16
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_K32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_X11
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_AA17
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_W46
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_S35
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_R42
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_L14
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_Y04
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_AA16
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_AA32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_AC26
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_X30
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_P41
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_I30
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_AC22
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_K43
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_B14
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_I08
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_K24
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_P38
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_T40
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_I16
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_AC22
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_AC28
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_AD02
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_K32
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_F42
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_C41
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_V39
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_X43
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_E42
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_C28
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_Z17
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_U27
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_F35
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_AD10
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_F20
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_F23
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_G29
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_K05
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_Z37
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_N47
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_J14
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_Y04
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_AD25
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_T24
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_AD22
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_AB31
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_AC35
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_U16
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_S08
# Warning: Could not find Cells.csv
# Warning: Could not find Cytoplasm.csv
# Warning: Could not find GolgiSpots.csv
# Warning: Could not find MitoObjects.csv
# Warning: Could not find MitoChildObjects.csv
# Warning: Could not find Nuclei.csv
# Warning: Could not find Nucleoli.csv
# Warning: Could not find NucleoliChildObjects.csv
# reduce() of empty iterable with no initial value
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_H28
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_J28
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_AD05
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_I14
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_Z14
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_E21
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_M11
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_L32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_AC41
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_M12
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_X22
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_AB41
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_I19
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_J27
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_R28
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_H40
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_F10
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_E15
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_AB03
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_I22
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_J21
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_D27
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_B39
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_D11
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_C12
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_E30
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_AC24
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_AE02
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_Y10
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_J18
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_AC29
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_T35
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_B06
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_D37
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_V02
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_AA16
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_Q42
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_AD46
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_H03
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_V47
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_R43
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_C25
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_L21
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_U15
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_AA16
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_B38
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_AD35
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_T32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_M19
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_Z38
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_G14
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_I25
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_F04
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_K39
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_S40
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_O20
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_C39
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_Z17
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_Q09
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_E46
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_M23
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_P32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_S11
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_I16
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_M26
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_T24
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_G45
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_P31
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_K29
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_C18
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_L27
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_AE06
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_M07
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_D45
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_N20
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_AB31
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_C46
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_Q02
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_C17
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_AE05
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_AC19
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_P19
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_M34
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_AB43
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_N20
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_AA30
# /mnt/data/cellprofiler-output/ko/gene-081_Plate5_gene-081_5_Q07
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_T06
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_W25
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_D22
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_AB22
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_L44
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_AB45
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_B29
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_I32
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_AB37
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_AC31
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_L15
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_J32
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_R33
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_Z05
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_Q41
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_I22
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_P06
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_R11
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_B22
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_P08
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_AA42
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_AE42
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_H38
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_Z18
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_AA16
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_K03
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_K07
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_B05
# /mnt/data/cellprofiler-output/ko/gene-081_Plate8_gene-081_8_X06
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_I30
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_N12
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_G18
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_L35
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_T12
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_C24
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_X40
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_O39
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_H17
# /mnt/data/cellprofiler-output/ko/gene-157_Plate5_gene-157_5_F43
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_J13
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_U27
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_P35
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_R41
# /mnt/data/cellprofiler-output/ko/gene-157_Plate1_gene-157_1_Y22
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_V07
# /mnt/data/cellprofiler-output/ko/gene-081_Plate3_gene-081_3_L32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate3_gene-157_3_AD26
# /mnt/data/cellprofiler-output/ko/gene-157_Plate6_gene-157_6_J27
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_H39
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_T29
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_C47
# /mnt/data/cellprofiler-output/ko/gene-157_Plate7_gene-157_7_N07
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_U15
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_K35
# /mnt/data/cellprofiler-output/ko/gene-081_Plate4_gene-081_4_O19
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_Z41
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_J34
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_W23
# /mnt/data/cellprofiler-output/ko/gene-157_Plate9_gene-157_9_Y16
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_K26
# /mnt/data/cellprofiler-output/ko/gene-081_Plate6_gene-081_6_L18
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_W42
# /mnt/data/cellprofiler-output/ko/gene-157_Plate8_gene-157_8_F14
# /mnt/data/cellprofiler-output/ko/gene-081_Plate2_gene-081_2_AB47
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_T23
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_AE07
# /mnt/data/cellprofiler-output/ko/gene-081_Plate7_gene-081_7_E24
# /mnt/data/cellprofiler-output/ko/gene-081_Plate9_gene-081_9_W16
# /mnt/data/cellprofiler-output/ko/gene-081_Plate1_gene-081_1_AE32
# /mnt/data/cellprofiler-output/ko/gene-157_Plate4_gene-157_4_H33
# /mnt/data/cellprofiler-output/ko/gene-157_Plate2_gene-157_2_F31

# %% [markdown]
# ```
# $ csvtk stats *.csv
# file                   num_cols  num_rows
# inhibitor_results.csv     6,538       892
# ko_results.csv            6,538       256
# ```
